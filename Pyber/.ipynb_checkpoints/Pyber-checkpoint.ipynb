# %%
#pyber
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import numpy as np
import pandas as pd
import seaborn as sns

# %%
city_data_df = pd.read_csv("raw_data/city_data.csv")
ride_data_df = pd.read_csv("raw_data/ride_data.csv")
combined_data_df = pd.merge(city_data_df, ride_data_df, on="city", how='outer')
# rider_groupedby_df = combined_data_df.sort_values(['city'],ascending=True).groupby('city')
# rider_groupedby_df = rider_groupedby_df['city','date','fare','ride_id','driver_count','type']
# rider_groupedby_df.head()

combined_data_table = combined_data_df[['city','date','fare','ride_id','driver_count','type']]
combined_data_table.sort_values('city')
# Out:
#                 city                 date   fare        ride_id  driver_count  \
# 1594    Alvarezhaven  2016-04-18 20:51:29  31.93  4267015736324            21
# 1595    Alvarezhaven  2016-08-01 00:39:48   6.42  8394540350728            21
# 1624    Alvarezhaven  2016-07-04 04:28:22  33.31   306054352684            21
# 1623    Alvarezhaven  2016-01-27 10:38:40   6.72  6152998520191            21
# 1622    Alvarezhaven  2016-05-16 15:33:14   6.45  8939751998750            21
# 1620    Alvarezhaven  2016-03-16 02:01:15  33.62  8974645194719            21
# 1619    Alvarezhaven  2016-06-16 18:29:05  32.46   858631473935            21
# 1618    Alvarezhaven  2016-02-15 11:14:12  31.74  5487020911007            21
# 1617    Alvarezhaven  2016-11-19 02:00:34   5.34  1108172306544            21
# 1616    Alvarezhaven  2016-01-25 06:02:25   5.16  2233026076010            21
# 1615    Alvarezhaven  2016-08-03 06:45:57   4.07  6100187302721            21
# 1614    Alvarezhaven  2016-05-20 12:26:56  42.00  7852567608457            21
# 1613    Alvarezhaven  2016-05-01 14:35:12  22.54  6435260355302            21
# 1612    Alvarezhaven  2016-01-21 07:25:48  22.83  3565582370530            21
# 1611    Alvarezhaven  2016-02-07 02:46:18  35.22  5405756761666            21
# 1621    Alvarezhaven  2016-09-19 16:01:49  27.51  6282665852239            21
# 1609    Alvarezhaven  2016-05-15 20:43:44  40.04  1806812593131            21
# 1596    Alvarezhaven  2016-09-01 22:57:12  18.09  1197329964911            21
# 1610    Alvarezhaven  2016-06-11 23:45:52  43.34  3938173695105            21
# 1597    Alvarezhaven  2016-08-18 07:12:06  20.74   357421158941            21
# 1599    Alvarezhaven  2016-10-31 05:33:55  20.23  4348900295000            21
# 1600    Alvarezhaven  2016-05-26 11:36:48  39.28  8878745717970            21
# 1601    Alvarezhaven  2016-01-28 23:53:55   9.87  2747592323442            21
# 1598    Alvarezhaven  2016-04-04 23:45:50  14.25  6431434271355            21
# 1603    Alvarezhaven  2016-09-16 14:36:24  20.61  8307812366044            21
# 1604    Alvarezhaven  2016-03-16 22:24:17  31.08  7413831046469            21
# 1608    Alvarezhaven  2016-09-23 21:51:59  17.67  3829336915201            21
# 1605    Alvarezhaven  2016-01-20 06:52:53  42.41  7825539032352            21
# 1606    Alvarezhaven  2016-06-25 22:46:06  24.16  9047320468692            21
# 1602    Alvarezhaven  2016-04-25 08:50:08  31.82  7948246793429            21
# ...              ...                  ...    ...            ...           ...
# 1432  Urban
# 1434  Urban
# 1455  Urban
# 1454  Urban
# 1453  Urban
# 1452  Urban
# 1451  Urban
# 1449  Urban
# 1448  Urban
# 1447  Urban
# 1446  Urban
# 1433  Urban
# 1445  Urban
# 1443  Urban
# 1442  Urban
# 1441  Urban
# 1440  Urban
# 1439  Urban
# 1438  Urban
# 1437  Urban
# 1436  Urban
# 1435  Urban
# 1444  Urban
# 1450  Urban
#
# [2407 rows x 6 columns]

# %%
cityGroupBy_df = combined_data_df.groupby(["city","type"])
avgFarePrice = round(cityGroupBy_df['fare'].mean(),2)
totalDrivers = cityGroupBy_df['driver_count'].sum()
riderCount = cityGroupBy_df['ride_id'].count()

pyber_analysis = pd.DataFrame({
                                       "Average Fare ($) Per City" : avgFarePrice,
                                       "Total Number of Drivers per city" : totalDrivers,
                                       "Total Number of Rides per city": riderCount
                                        })
pyber_summary_analysis = pyber_analysis[["Average Fare ($) Per City","Total Number of Drivers per city","Total Number of Rides per city"]]
pyber_summary_analysis
# Out:
#                                Average Fare ($) Per City  \
# city                 type
# Alvarezhaven         Urban                         23.93
# Alyssaberg           Urban                         20.61
# Anitamouth           Suburban                      37.32
# Antoniomouth         Urban                         23.62
# Aprilchester         Urban                         21.98
# Arnoldview           Urban                         25.11
# Campbellport         Suburban                      33.71
# Carrollbury          Suburban                      36.61
# Carrollfort          Urban                         25.40
# Clarkstad            Suburban                      31.05
# Conwaymouth          Suburban                      34.59
# Davidtown            Urban                         22.98
# Davistown            Urban                         21.50
# East Cherylfurt      Suburban                      31.42
# East Douglas         Urban                         26.17
# East Erin            Urban                         24.48
# East Jenniferchester Suburban                      32.60
# East Leslie          Rural                         33.66
# East Stephen         Rural                         39.05
# East Troybury        Rural                         33.24
# Edwardsbury          Urban                         26.88
# Erikport             Rural                         30.04
# Eriktown             Urban                         25.48
# Floresberg           Suburban                      32.31
# Fosterside           Urban                         23.03
# Hernandezshire       Rural                         32.00
# Horneland            Rural                         21.48
# Jacksonfort          Rural                         32.01
# Jacobfort            Urban                         24.78
# Jasonfort            Suburban                      27.83
# ...                                                  ...
# South Roy            Urban                         26.03
# South Shannonborough Suburban                      26.52
# Spencertown          Urban                         23.68
# Stevensport          Rural                         31.95
# Stewartview          Urban                         21.61
# Swansonbury          Urban                         27.46
# Thomastown           Suburban                      30.31
# Tiffanyton           Suburban                      28.51
# Torresshire          Urban                         24.21
# Travisville          Urban                         27.22
# Vickimouth           Urban                         21.47
# Webstertown          Suburban                      29.72
# West Alexis          Urban                         19.52
# West Brandy          Urban                         24.16
# West Brittanyton     Urban                         25.44
# West Dawnfurt        Urban                         22.33
# West Evan            Suburban                      27.01
# West Jefferyfurt     Urban                         21.07
# West Kevintown       Rural                         21.53
# West Oscar           Urban                         24.28
# West Pamelaborough   Suburban                      33.80
# West Paulport        Suburban                      33.28
# West Peter           Urban                         24.88
# West Sydneyhaven     Urban                         22.37
# West Tony            Suburban                      29.61
# Williamchester       Suburban                      34.28
# Hernandezshire       Rural                                  9
# Horneland            Rural                                  4
# Jacksonfort          Rural                                  6
# Jacobfort            Urban                                 31
# Jasonfort            Suburban                              12
# ...                                                       ...
# South Roy            Urban                                 22
# South Shannonborough Suburban                              15
# Spencertown          Urban                                 26
# Stevensport          Rural                                  5
# Stewartview          Urban                                 30
# Swansonbury          Urban                                 34
# Thomastown           Suburban                              24
# Tiffanyton           Suburban                              13
# Torresshire          Urban                                 26
# Travisville          Urban                                 23
# Vickimouth           Urban                                 15
# Webstertown          Suburban                              16
# West Alexis          Urban                                 20
# West Brandy          Urban                                 30
# West Brittanyton     Urban                                 24
# West Dawnfurt        Urban                                 29
# West Evan            Suburban                              12
# West Jefferyfurt     Urban                                 21
# West Kevintown       Rural                                  7
# West Oscar           Urban                                 29
# West Pamelaborough   Suburban                              14
# West Paulport        Suburban                              17
# West Peter           Urban                                 31
# West Sydneyhaven     Urban                                 18
# West Tony            Suburban                              19
# Williamchester       Suburban                              11
# Williamshire         Urban                                 31
# Wiseborough          Urban                                 19
# Yolandafurt          Urban                                 20
# Zimmermanmouth       Urban                                 24
#
# [125 rows x 3 columns]

# %%
plt.title("Pyber Ride Sharing Data (2016)")
plt.xlabel("Total Number of Rides per City (Per City)")
plt.ylabel("Average Fare ($)")

# Set the upper and lower limits of our y axis
plt.ylim(0,45)

# Set the upper and lower limits of our x axis
plt.xlim(0,40)


pyber_summary_analysis.plot.scatter(x='riderCount',y='avgFarePrice')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'riderCount'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-98-ac2eae53853f> in <module>()
#      10
#      11
# ---> 12 pyber_summary_analysis.plot.scatter(x='riderCount',y='avgFarePrice')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in scatter(self, x, y, s, c, **kwds)
#    2803         axes : matplotlib.AxesSubplot or np.array of them
#    2804         """
# -> 2805         return self(kind='scatter', x=x, y=y, c=c, s=s, **kwds)
#    2806
#    2807     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2625                           fontsize=fontsize, colormap=colormap, table=table,
#    2626                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2627                           sort_columns=sort_columns, **kwds)
#    2628     __call__.__doc__ = plot_frame.__doc__
#    2629
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1867                  yerr=yerr, xerr=xerr,
#    1868                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1869                  **kwds)
#    1870
#    1871
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1650         if isinstance(data, DataFrame):
#    1651             plot_obj = klass(data, x=x, y=y, subplots=subplots, ax=ax,
# -> 1652                              kind=kind, **kwds)
#    1653         else:
#    1654             raise ValueError("plot kind %r can only be used for data frames"
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in __init__(self, data, x, y, s, c, **kwargs)
#     808             # the handling of this argument later
#     809             s = 20
# --> 810         super(ScatterPlot, self).__init__(data, x, y, s=s, **kwargs)
#     811         if is_integer(c) and not self.data.columns.holds_integer():
#     812             c = self.data.columns[c]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in __init__(self, data, x, y, **kwargs)
#     782         if is_integer(y) and not self.data.columns.holds_integer():
#     783             y = self.data.columns[y]
# --> 784         if len(self.data[x]._get_numeric_data()) == 0:
#     785             raise ValueError(self._kind + ' requires x column to be numeric')
#     786         if len(self.data[y]._get_numeric_data()) == 0:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'riderCount'
