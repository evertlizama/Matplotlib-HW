# %%
#pyber
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import numpy as np
import pandas as pd
import seaborn as sns

# %%
city_data_df = pd.read_csv("raw_data/city_data.csv")
ride_data_df = pd.read_csv("raw_data/ride_data.csv")
combined_data_df = pd.merge(city_data_df, ride_data_df, on="city", how='outer')
# rider_groupedby_df = combined_data_df.sort_values(['city'],ascending=True).groupby('city')
# rider_groupedby_df = rider_groupedby_df['city','date','fare','ride_id','driver_count','type']
# rider_groupedby_df.head()

combined_data_table = combined_data_df[['city','date','fare','ride_id','driver_count','type']]
combined_data_table.sort_values('city')
# Out:
#                      city  driver_count      type
# 0              Kelseyland            63     Urban
# 1              Nguyenbury             8     Urban
# 2            East Douglas            12     Urban
# 3           West Dawnfurt            34     Urban
# 4          Rodriguezburgh            52     Urban
# 5       South Josephville             4     Urban
# 6        West Sydneyhaven            70     Urban
# 7             Travisville            37     Urban
# 8             Torresshire            70     Urban
# 9               Lisaville            66     Urban
# 10              Mooreview            34     Urban
# 11             Smithhaven            67     Urban
# 12            Carrollfort            55     Urban
# 13        Port Josephfurt            28     Urban
# 14       Lake Jeffreyland            15     Urban
# 15            South Louis            12     Urban
# 16             West Peter            61     Urban
# 17        Kimberlychester            13     Urban
# 18             Alyssaberg            67     Urban
# 19               Sarabury            46     Urban
# 20            Yolandafurt             7     Urban
# 21            Edwardsbury            11     Urban
# 22        New Andreamouth            42     Urban
# 23              New David            31     Urban
# 24             Arnoldview            41     Urban
# 25           Williamshire            70     Urban
# 26               Lisatown            47     Urban
# 27              New Aaron            60     Urban
# 28            Swansonbury            64     Urban
# 29             Fosterside            69     Urban
# ..                    ...           ...       ...
# 96               New Lynn            20  Suburban
# 97              Port Jose            11  Suburban
# 98               Johnland            13  Suburban
# 99              West Tony            17  Suburban
# 100            Port James             3  Suburban
# 101          Campbellport            26  Suburban
# 102          Port Guytown            26  Suburban
# 103           Webstertown            26  Suburban
# 104             Clarkstad            21  Suburban
# 105       North Tracyfort            18  Suburban
# 106           Martinmouth             5  Suburban
# 107      New Jessicamouth            22  Suburban
# 108  South Elizabethmouth             3     Rural
# 109         East Troybury             3     Rural
# 110             Kinghaven             3     Rural
# 111          New Johnbury             6     Rural
# 112              Erikport             3     Rural
# 113           Jacksonfort             6     Rural
# 114           Shelbyhaven             9     Rural
# 115           Matthewside             4     Rural
# 116          Kennethburgh             3     Rural
# 117          South Joseph             3     Rural
# 118         Manuelchester             7     Rural
# 119           Stevensport             6     Rural
# 120         North Whitney            10     Rural
# 121          East Stephen             6     Rural
# 122           East Leslie             9     Rural
# 123        Hernandezshire            10     Rural
# 124             Horneland             8     Rural
# 125        West Kevintown             5     Rural
#
# [126 rows x 3 columns]

# %%
cityGroupBy_df = combined_data_df.groupby(["city","type"])
cityData = cityGroupBy_df.sum()
avgFarePrice = round(cityGroupBy_df['fare'].mean(),2)
riderCount = cityGroupBy_df['ride_id'].count()
totalDrivers = pd.to_numeric(cityData['driver_count']/riderCount,downcast='signed')


pyber_analysis = pd.DataFrame({
                                       "Average Fare ($) Per City" : avgFarePrice,
                                       "Total Number of Drivers per city" : totalDrivers,
                                       "Total Number of Rides per city": riderCount
                                        })
pyber_summary_analysis = pyber_analysis[["Average Fare ($) Per City","Total Number of Drivers per city","Total Number of Rides per city"]]

pyber_summary_analysis_resetted = pyber_summary_analysis.reset_index()
pyber_summary_analysis_resetted = pyber_summary_analysis_resetted.rename(columns={'type':'City Type'})
pyber_summary_analysis_resetted = pyber_summary_analysis_resetted.set_index('city') 
pyber_summary_analysis_resetted
# Out:
#                      City Type  Average Fare ($) Per City  \
# city
# Alvarezhaven             Urban                      23.93
# Alyssaberg               Urban                      20.61
# Anitamouth            Suburban                      37.32
# Antoniomouth             Urban                      23.62
# Aprilchester             Urban                      21.98
# Arnoldview               Urban                      25.11
# Campbellport          Suburban                      33.71
# Carrollbury           Suburban                      36.61
# Carrollfort              Urban                      25.40
# Clarkstad             Suburban                      31.05
# Conwaymouth           Suburban                      34.59
# Davidtown                Urban                      22.98
# Davistown                Urban                      21.50
# East Cherylfurt       Suburban                      31.42
# East Douglas             Urban                      26.17
# East Erin                Urban                      24.48
# East Jenniferchester  Suburban                      32.60
# East Leslie              Rural                      33.66
# East Stephen             Rural                      39.05
# East Troybury            Rural                      33.24
# Edwardsbury              Urban                      26.88
# Erikport                 Rural                      30.04
# Eriktown                 Urban                      25.48
# Floresberg            Suburban                      32.31
# Fosterside               Urban                      23.03
# Hernandezshire           Rural                      32.00
# Horneland                Rural                      21.48
# Jacksonfort              Rural                      32.01
# Jacobfort                Urban                      24.78
# Jasonfort             Suburban                      27.83
# ...                        ...                        ...
# South Roy                Urban                      26.03
# South Shannonborough  Suburban                      26.52
# Spencertown              Urban                      23.68
# Stevensport              Rural                      31.95
# Stewartview              Urban                      21.61
# Swansonbury              Urban                      27.46
# Thomastown            Suburban                      30.31
# Tiffanyton            Suburban                      28.51
# Torresshire              Urban                      24.21
# Travisville              Urban                      27.22
# Vickimouth               Urban                      21.47
# Webstertown           Suburban                      29.72
# West Alexis              Urban                      19.52
# West Brandy              Urban                      24.16
# West Brittanyton         Urban                      25.44
# West Dawnfurt            Urban                      22.33
# West Evan             Suburban                      27.01
# West Jefferyfurt         Urban                      21.07
# West Kevintown           Rural                      21.53
# West Oscar               Urban                      24.28
# West Pamelaborough    Suburban                      33.80
# West Paulport         Suburban                      33.28
# West Peter               Urban                      24.88
# West Sydneyhaven         Urban                      22.37
# West Tony             Suburban                      29.61
# Williamchester        Suburban                      34.28
# Williamshire             Urban                      26.99
# Wiseborough              Urban                      22.68
# Yolandafurt              Urban                      27.21
# Zimmermanmouth           Urban                      28.30
#
#                       Total Number of Drivers per city  \
# city
# Alvarezhaven                                        21
# Alyssaberg                                          67
# Anitamouth                                          16
# Antoniomouth                                        21
# Aprilchester                                        49
# Arnoldview                                          41
# Campbellport                                        26
# Carrollbury                                          4
# Carrollfort                                         55
# Clarkstad                                           21
# Conwaymouth                                         18
# Davidtown                                           73
# Davistown                                           25
# East Cherylfurt                                      9
# East Douglas                                        12
# East Erin                                           43
# East Jenniferchester                                22
# East Leslie                                          9
# East Stephen                                         6
# East Troybury                                        3
# Edwardsbury                                         11
# Erikport                                             3
# Eriktown                                            15
# Floresberg                                           7
# Fosterside                                          69
# Hernandezshire                                      10
# Horneland                                            8
# Jacksonfort                                          6
# Jacobfort                                           52
# Jasonfort                                           25
# ...                                                ...
# South Roy                                           35
# South Shannonborough                                 9
# Spencertown                                         68
# Stevensport                                          6
# Stewartview                                         49
# Swansonbury                                         64
# Thomastown                                           1
# Tiffanyton                                          21
# Torresshire                                         70
# Travisville                                         37
# Vickimouth                                          13
# Webstertown                                         26
# West Alexis                                         47
# West Brandy                                         12
# West Brittanyton                                     9
# West Dawnfurt                                       34
# West Evan                                            4
# West Jefferyfurt                                    65
# West Kevintown                                       5
# West Oscar                                          11
# West Pamelaborough                                  27
# West Paulport                                        5
# West Peter                                          61
# West Sydneyhaven                                    70
# West Tony                                           17
# Williamchester                                      26
# Williamshire                                        70
# Wiseborough                                         55
# Yolandafurt                                          7
# Zimmermanmouth                                      45
#
#                       Total Number of Rides per city
# city
# Alvarezhaven                                      31
# Alyssaberg                                        26
# Anitamouth                                         9
# Antoniomouth                                      22
# Aprilchester                                      19
# Arnoldview                                        31
# Campbellport                                      15
# Carrollbury                                       10
# Carrollfort                                       29
# Clarkstad                                         12
# Conwaymouth                                       11
# Davidtown                                         21
# Davistown                                         25
# East Cherylfurt                                   13
# East Douglas                                      22
# East Erin                                         28
# East Jenniferchester                              19
# East Leslie                                       11
# East Stephen                                      10
# East Troybury                                      7
# Edwardsbury                                       27
# Erikport                                           8
# Eriktown                                          19
# Floresberg                                        10
# Fosterside                                        24
# Hernandezshire                                     9
# Horneland                                          4
# Jacksonfort                                        6
# Jacobfort                                         31
# Jasonfort                                         12
# ...                                              ...
# South Roy                                         22
# South Shannonborough                              15
# Spencertown                                       26
# Stevensport                                        5
# Stewartview                                       30
# Swansonbury                                       34
# Thomastown                                        24
# Tiffanyton                                        13
# Torresshire                                       26
# Travisville                                       23
# Vickimouth                                        15
# Webstertown                                       16
# West Alexis                                       20
# West Brandy                                       30
# West Brittanyton                                  24
# West Dawnfurt                                     29
# West Evan                                         12
# West Jefferyfurt                                  21
# West Kevintown                                     7
# West Oscar                                        29
# West Pamelaborough                                14
# West Paulport                                     17
# West Peter                                        31
# West Sydneyhaven                                  18
# West Tony                                         19
# Williamchester                                    11
# Williamshire                                      31
# Wiseborough                                       19
# Yolandafurt                                       20
# Zimmermanmouth                                    24
#
# [125 rows x 4 columns]

# %%
#pyber_summary_analysis_resetted def attribute_color(t):
    
colors = {'Rural': 'gold', 'Suburban': 'lightskyblue', 'Urban': 'lightcoral'}
plt.figure(figsize=(10,10))   

color_region = list()
 
for i, r in pyber_summary_analysis_resetted.iterrows():
    plt.scatter(x = r['Total Number of Rides per city'],
            y = r['Average Fare ($) Per City'],
            s = r['Total Number of Drivers per city']*10,
            marker='o',
            facecolors=colors.get(r['City Type']),
            edgecolors='black',
            )
plt.title('Pyber Ride Sharing Data (2018)', fontsize=20)
plt.xlabel('Total Number of Rides per City')
plt.ylabel('Average Fare ($)')
plt.xlim(0,45)
plt.ylim(15,45)
plt.show()
